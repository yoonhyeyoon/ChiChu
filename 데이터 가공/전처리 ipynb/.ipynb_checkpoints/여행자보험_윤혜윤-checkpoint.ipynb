# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
df = pd.read_csv("preprocessed_5.csv")
df
# Out:
#         JOIN_SN  JOIN_SN_TYP  BTH_YR  GENDER  IS_KRN  AGE  SCTR_CD   COM_SN  \
# 0        233370            1    1997       2       1   26        8  6900284
# 1        233370            1    1997       2       1   26        8  6900284
# 2        233370            1    1997       2       1   26        8  6900284
# 3        233370            1    1997       2       1   26        8  6900284
# 4        233370            1    1997       2       1   26        8  6900284
# ...         ...          ...     ...     ...     ...  ...      ...      ...
# 544221   541575            1    1978       1       1   45        6  7829020
# 544222   541575            1    1978       1       1   45        6  7829020
# 544223   541575            1    1978       1       1   45        6  7829020
# 544224   541575            1    1978       1       1   45        6  7829020
# 544225   541575            1    1978       1       1   45        6  7829020
#
#          POL_SN  GIS_CD  ...  CT_ST_DT  CT_END_DT  CT_PY_AMT  CT_PY_CYCLE_CD  \
# 0        344059      33  ...    201806     209606         70               2
# 1        344059      33  ...    201806     209606         70               2
# 2        344059      33  ...    201806     209606         70               2
# 3        344059      33  ...    201806     209606         70               2
# 4        344059      33  ...    201806     209606         70               2
# ...         ...     ...  ...       ...        ...        ...             ...
# 544221  5507225      26  ...    202006     207306         79               2
# 544222  5507225      26  ...    202006     207306         79               2
# 544223  5507225      26  ...    202006     207306         79               2
# 544224  5507225      26  ...    202006     207306         79               2
# 544225  5507225      26  ...    202006     207306         79               2
#
#         CT_PY_PD  CT_CHNL_CD  MGG_GRP_CD  MGG_CD MGG_CNT MGG_AMT_SUM
# 0             20           1          A5   A5309       1        4500
# 1             20           1          A4   A4102       1       18000
# 2             20           1          A5   A5107       1        1800
# 3             20           1          A6   A6109       1         100
# 4             20           1          A4   A4200       1       18000
# ...          ...         ...         ...     ...     ...         ...
# 544221        30           1          A6   A6112       1         240
# 544222        30           1          A1   A1300       2       80000
# 544223        30           1          A5   A5100       2         240
# 544224        30           1          A5   A5107       1        4000
# 544225        30           1         A99   A9999       2        8000
#
# [544226 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['JOIN_SN', 'JOIN_SN_TYP', 'BTH_YR', 'GENDER', 'IS_KRN', 'AGE',
#        'SCTR_CD', 'COM_SN', 'POL_SN', 'GIS_CD', 'INS_GBN_CD', 'INS_CT_STAT_CD',
#        'CT_ST_DT', 'CT_END_DT', 'CT_PY_AMT', 'CT_PY_CYCLE_CD', 'CT_PY_PD',
#        'CT_CHNL_CD', 'MGG_GRP_CD', 'MGG_CD', 'MGG_CNT', 'MGG_AMT_SUM'],
#       dtype='object')

# %%
df_t = df[df.INS_GBN_CD == 14]
df_t
# Out:
#         JOIN_SN  JOIN_SN_TYP  BTH_YR  GENDER  IS_KRN  AGE  SCTR_CD   COM_SN  \
# 2028     195908            1    1993       1       1   30        6  7163853
# 2029     195908            1    1993       1       1   30        6  7163853
# 2747     880454            1    1992       2       1   31        6     2443
# 2748     880454            1    1992       2       1   31        6     2443
# 2749     880454            1    1992       2       1   31        6     2443
# ...         ...          ...     ...     ...     ...  ...      ...      ...
# 543295   979312            1    2002       1       1   21        6  5695546
# 543296   979312            1    2002       1       1   21        6  5695546
# 543297   979312            1    2002       1       1   21        6  5695546
# 543298   979312            1    2002       1       1   21        6  5695546
# 543299   979312            1    2002       1       1   21        6  5695546
#
#          POL_SN  GIS_CD  ...  CT_ST_DT  CT_END_DT  CT_PY_AMT  CT_PY_CYCLE_CD  \
# 2028    8006336      21  ...    201907     202001        250               1
# 2029    8006336      21  ...    201907     202001        250               1
# 2747     545678      31  ...    201808     201809         16               1
# 2748     545678      31  ...    201808     201809         16               1
# 2749     545678      31  ...    201808     201809         16               1
# ...         ...     ...  ...       ...        ...        ...             ...
# 543295  2137903      23  ...    201811     201812         18               1
# 543296  2137903      23  ...    201811     201812         18               1
# 543297  2137903      23  ...    201811     201812         18               1
# 543298  2137903      23  ...    201811     201812         18               1
# 543299  2137903      23  ...    201811     201812         18               1
#
#         CT_PY_PD  CT_CHNL_CD  MGG_GRP_CD  MGG_CD MGG_CNT MGG_AMT_SUM
# 2028           0           1          A1   A1399       1       32000
# 2029           0           1          A1   A1399       1       32000
# 2747           0           7          A4   A4199       1         160
# 2748           0           7          A1   A1100       1       16000
# 2749           0           7          A3   A3101       1       10000
# ...          ...         ...         ...     ...     ...         ...
# 543295         0           5         A94   A9499       1        1300
# 543296         0           5          A3   A3101       1       10000
# 543297         0           5          A1   A1399       1      270000
# 543298         0           5         A94   A9499       1        1300
# 543299         0           5          A3   A3101       1       10000
#
# [1576 rows x 22 columns]

# %% [markdown]
# ## 담보(코드, 그룹코드) 구성

# %%
df_t.MGG_GRP_CD.unique()
# Out:
# array(['A1', 'A4', 'A3', 'A6', 'A99', 'A94'], dtype=object)

# %%
grouped = df_t.groupby("INS_GBN_CD")

# %%
for key, group in grouped:
    print("보험종류", key)
    for n in group.MGG_GRP_CD.unique():
        print(n, df_t[df_t["MGG_GRP_CD"] == n].MGG_CD.unique())
# Out:
# 보험종류 14
# A1 ['A1399' 'A1100' 'A1300' 'A1199']
# A4 ['A4199']
# A3 ['A3101' 'A3300' 'A3399' 'A3199' 'A3100' 'A3303']
# A6 ['A6300' 'A6100' 'A6999']
# A99 ['A9999']
# A94 ['A9499']

# %%
# 치환
df_t['MGG_GRP_CD_'] = df_t["MGG_GRP_CD"].replace(['A1', 'A4', 'A3', 'A6', 'A99', 'A94'],
                          ['사망', '진단', '후유장해', '입원일당', '기타', '위로금'], inplace=False)
# Out:
# C:\Users\MULTIC~1\AppData\Local\Temp/ipykernel_10528/225054449.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t['MGG_GRP_CD_'] = df_t["MGG_GRP_CD"].replace(['A1', 'A4', 'A3', 'A6', 'A99', 'A94'],

# %%
df_t
# Out:
#         JOIN_SN  JOIN_SN_TYP  BTH_YR  GENDER  IS_KRN  AGE  SCTR_CD   COM_SN  \
# 2028     195908            1    1993       1       1   30        6  7163853
# 2029     195908            1    1993       1       1   30        6  7163853
# 2747     880454            1    1992       2       1   31        6     2443
# 2748     880454            1    1992       2       1   31        6     2443
# 2749     880454            1    1992       2       1   31        6     2443
# ...         ...          ...     ...     ...     ...  ...      ...      ...
# 543295   979312            1    2002       1       1   21        6  5695546
# 543296   979312            1    2002       1       1   21        6  5695546
# 543297   979312            1    2002       1       1   21        6  5695546
# 543298   979312            1    2002       1       1   21        6  5695546
# 543299   979312            1    2002       1       1   21        6  5695546
#
#          POL_SN  GIS_CD  ...  CT_END_DT  CT_PY_AMT  CT_PY_CYCLE_CD  CT_PY_PD  \
# 2028    8006336      21  ...     202001        250               1         0
# 2029    8006336      21  ...     202001        250               1         0
# 2747     545678      31  ...     201809         16               1         0
# 2748     545678      31  ...     201809         16               1         0
# 2749     545678      31  ...     201809         16               1         0
# ...         ...     ...  ...        ...        ...             ...       ...
# 543295  2137903      23  ...     201812         18               1         0
# 543296  2137903      23  ...     201812         18               1         0
# 543297  2137903      23  ...     201812         18               1         0
# 543298  2137903      23  ...     201812         18               1         0
# 543299  2137903      23  ...     201812         18               1         0
#
#         CT_CHNL_CD  MGG_GRP_CD  MGG_CD  MGG_CNT MGG_AMT_SUM MGG_GRP_CD_
# 2028             1          A1   A1399        1       32000          사망
# 2029             1          A1   A1399        1       32000          사망
# 2747             7          A4   A4199        1         160          진단
# 2748             7          A1   A1100        1       16000          사망
# 2749             7          A3   A3101        1       10000        후유장해
# ...            ...         ...     ...      ...         ...         ...
# 543295           5         A94   A9499        1        1300         위로금
# 543296           5          A3   A3101        1       10000        후유장해
# 543297           5          A1   A1399        1      270000          사망
# 543298           5         A94   A9499        1        1300         위로금
# 543299           5          A3   A3101        1       10000        후유장해
#
# [1576 rows x 23 columns]

# %%
df_t.groupby("MGG_GRP_CD_")

# %%
grouped = df_t.groupby("MGG_GRP_CD_").count()

mgg_arr = []
labels = []

for i in df_t.MGG_GRP_CD_.unique():
    mgg_arr.append(grouped["JOIN_SN"][i])
    labels.append(i)
plt.pie(mgg_arr, labels=labels)
plt.show()

# %% [markdown]
# ## 납입주기코드 먼저 봐서 연납.월납.일시납 중 뭐가 많은지

# %%
df_t.groupby("CT_PY_CYCLE_CD").count() # 모두 1 => 일시납
# Out:
#                 JOIN_SN  JOIN_SN_TYP  BTH_YR  GENDER  IS_KRN   AGE  SCTR_CD  \
# CT_PY_CYCLE_CD
# 1                  1576         1576    1576    1576    1576  1576     1576
#
#                 COM_SN  POL_SN  GIS_CD  ...  CT_ST_DT  CT_END_DT  CT_PY_AMT  \
# CT_PY_CYCLE_CD                          ...
# 1                 1576    1576    1576  ...      1576       1576       1576
#
#                 CT_PY_PD  CT_CHNL_CD  MGG_GRP_CD  MGG_CD  MGG_CNT  \
# CT_PY_CYCLE_CD
# 1                   1576        1576        1576    1576     1576
#
#                 MGG_AMT_SUM  MGG_GRP_CD_
# CT_PY_CYCLE_CD
# 1                      1576         1576
#
# [1 rows x 22 columns]

# %% [markdown]
# ## 가장 많이 선택된 납입코드의 납입기간은 어떤 비율인지.

# %%
df_t[df_t.CT_PY_CYCLE_CD == 1].groupby("CT_PY_PD").count().JOIN_SN
# Out:
# CT_PY_PD
# 0    1562
# 1      14
# Name: JOIN_SN, dtype: int64

# %% [markdown]
# ## 보험기간(종기월 - 시기월)의 비율을 어떠한지

# %%
df_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1576 entries, 2028 to 543299
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   JOIN_SN         1576 non-null   int64
#  1   JOIN_SN_TYP     1576 non-null   int64
#  2   BTH_YR          1576 non-null   int64
#  3   GENDER          1576 non-null   int64
#  4   IS_KRN          1576 non-null   int64
#  5   AGE             1576 non-null   int64
#  6   SCTR_CD         1576 non-null   int64
#  7   COM_SN          1576 non-null   int64
#  8   POL_SN          1576 non-null   int64
#  9   GIS_CD          1576 non-null   int64
#  10  INS_GBN_CD      1576 non-null   int64
#  11  INS_CT_STAT_CD  1576 non-null   int64
#  12  CT_ST_DT        1576 non-null   int64
#  13  CT_END_DT       1576 non-null   int64
#  14  CT_PY_AMT       1576 non-null   int64
#  15  CT_PY_CYCLE_CD  1576 non-null   int64
#  16  CT_PY_PD        1576 non-null   int64
#  17  CT_CHNL_CD      1576 non-null   int64
#  18  MGG_GRP_CD      1576 non-null   object
#  19  MGG_CD          1576 non-null   object
#  20  MGG_CNT         1576 non-null   int64
#  21  MGG_AMT_SUM     1576 non-null   int64
#  22  MGG_GRP_CD_     1576 non-null   object
# dtypes: int64(20), object(3)
# memory usage: 295.5+ KB

# %%
df_t[["CT_END_DT", "CT_ST_DT"]].head(50)
# Out:
#        CT_END_DT  CT_ST_DT
# 2028      202001    201907
# 2029      202001    201907
# 2747      201809    201808
# 2748      201809    201808
# 2749      201809    201808
# 2750      201809    201808
# 2751      201809    201808
# 2752      201809    201808
# 2753      201809    201808
# 2754      201809    201808
# 2755      201809    201808
# 2756      201809    201808
# 2757      201809    201808
# 2758      201809    201808
# 2759      201809    201808
# 2760      201809    201808
# 2761      201809    201808
# 2762      201809    201808
# 2763      201809    201808
# 2764      201809    201808
# 3476      201908    201902
# 3477      201908    201902
# 4261      201807    201806
# 4262      201807    201806
# 4263      201807    201806
# 4264      201807    201806
# 4265      201807    201806
# 4266      201807    201806
# 5416      201901    201812
# 5417      201901    201812
# 5418      201901    201812
# 5419      201901    201812
# 5420      201901    201812
# 5421      201901    201812
# 12907     201810    201810
# 12908     201810    201810
# 12909     201810    201810
# 13736     201912    201911
# 13737     201912    201911
# 13738     201912    201911
# 13739     201912    201911
# 13740     201912    201911
# 13741     201912    201911
# 15325     202004    202002
# 15326     202004    202002
# 15327     202004    202002
# 15328     202004    202002
# 15329     202004    202002
# 15330     202004    202002
# 17123     201903    201803

# %%
df_t['CT_END_DT'] = pd.to_datetime(df_t['CT_END_DT'], format='%Y%m', errors='coerce')
df_t['CT_ST_DT'] = pd.to_datetime(df_t['CT_ST_DT'], format='%Y%m', errors='coerce')
# Out:
# C:\Users\MULTIC~1\AppData\Local\Temp/ipykernel_10528/3798556681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t['CT_END_DT'] = pd.to_datetime(df_t['CT_END_DT'], format='%Y%m', errors='coerce')
# C:\Users\MULTIC~1\AppData\Local\Temp/ipykernel_10528/3798556681.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t['CT_ST_DT'] = pd.to_datetime(df_t['CT_ST_DT'], format='%Y%m', errors='coerce')

# %%
# 보장기간(CT_PD) 컬럼 생성

df_t['CT_PD'] = (df_t['CT_END_DT'] - df_t['CT_ST_DT']).dt.days
# Out:
# C:\Users\MULTIC~1\AppData\Local\Temp/ipykernel_10528/1977236707.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t['CT_PD'] = (df_t['CT_END_DT'] - df_t['CT_ST_DT']).dt.days

# %%
df_t[["CT_END_DT", "CT_ST_DT", "CT_PD"]].head(50)
# Out:
#        CT_END_DT   CT_ST_DT  CT_PD
# 2028  2020-01-01 2019-07-01    184
# 2029  2020-01-01 2019-07-01    184
# 2747  2018-09-01 2018-08-01     31
# 2748  2018-09-01 2018-08-01     31
# 2749  2018-09-01 2018-08-01     31
# 2750  2018-09-01 2018-08-01     31
# 2751  2018-09-01 2018-08-01     31
# 2752  2018-09-01 2018-08-01     31
# 2753  2018-09-01 2018-08-01     31
# 2754  2018-09-01 2018-08-01     31
# 2755  2018-09-01 2018-08-01     31
# 2756  2018-09-01 2018-08-01     31
# 2757  2018-09-01 2018-08-01     31
# 2758  2018-09-01 2018-08-01     31
# 2759  2018-09-01 2018-08-01     31
# 2760  2018-09-01 2018-08-01     31
# 2761  2018-09-01 2018-08-01     31
# 2762  2018-09-01 2018-08-01     31
# 2763  2018-09-01 2018-08-01     31
# 2764  2018-09-01 2018-08-01     31
# 3476  2019-08-01 2019-02-01    181
# 3477  2019-08-01 2019-02-01    181
# 4261  2018-07-01 2018-06-01     30
# 4262  2018-07-01 2018-06-01     30
# 4263  2018-07-01 2018-06-01     30
# 4264  2018-07-01 2018-06-01     30
# 4265  2018-07-01 2018-06-01     30
# 4266  2018-07-01 2018-06-01     30
# 5416  2019-01-01 2018-12-01     31
# 5417  2019-01-01 2018-12-01     31
# 5418  2019-01-01 2018-12-01     31
# 5419  2019-01-01 2018-12-01     31
# 5420  2019-01-01 2018-12-01     31
# 5421  2019-01-01 2018-12-01     31
# 12907 2018-10-01 2018-10-01      0
# 12908 2018-10-01 2018-10-01      0
# 12909 2018-10-01 2018-10-01      0
# 13736 2019-12-01 2019-11-01     30
# 13737 2019-12-01 2019-11-01     30
# 13738 2019-12-01 2019-11-01     30
# 13739 2019-12-01 2019-11-01     30
# 13740 2019-12-01 2019-11-01     30
# 13741 2019-12-01 2019-11-01     30
# 15325 2020-04-01 2020-02-01     60
# 15326 2020-04-01 2020-02-01     60
# 15327 2020-04-01 2020-02-01     60
# 15328 2020-04-01 2020-02-01     60
# 15329 2020-04-01 2020-02-01     60
# 15330 2020-04-01 2020-02-01     60
# 17123 2019-03-01 2018-03-01    365

# %%
# df_t[df_t.CT_PD == 0][["CT_END_DT", "CT_ST_DT"]]

# %%
df_t.CT_PD.describe()
# Out:
# count    1576.000000
# mean       63.686548
# std        94.474947
# min         0.000000
# 25%        30.000000
# 50%        31.000000
# 75%        60.000000
# max       366.000000
# Name: CT_PD, dtype: float64

# %%
df_t.CT_PD.unique()
# Out:
# array([184,  31, 181,  30,   0,  60, 365, 213, 183,  28,  61, 153,  59,
#        122, 366, 306, 305,  29, 123, 244, 214, 334,  90,  91,  92, 150,
#         62, 152, 303, 243, 304, 212, 120, 335], dtype=int64)

# %%
# 보장기간이 한달인 경우의 납입보험료
# df_t[df_t.CT_PD == 1].groupby("CT_PY_AMT").count()

# %%
# 보장기간 한달의 납입금액 비율 시각화 (천단위)
df_group = df_t[df_t.CT_PD == 1].groupby("CT_PY_AMT").count()
# df_group = df_t.groupby("CT_PD").count()

CT_PD_arr = []
labels=[]
for i in df_t[df_t.CT_PD == 1].CT_PY_AMT.unique():
    CT_PD_arr.append(df_group["JOIN_SN"][i])
    labels.append(i)
plt.pie(CT_PD_arr, labels=labels)
plt.show()

# %%
# 보장기간 비율 시각화 (월단위)

df_group = df_t.groupby("CT_PD").count()

CT_PD_arr = []
labels=[]
for i in df_t.CT_PD.unique():
    CT_PD_arr.append(df_group["JOIN_SN"][i])
    labels.append(i)
plt.pie(CT_PD_arr, labels=labels)
plt.show()

# %%
# 한달이하, 한달
# len(df_t[df_t["CT_PD"] == 0]), len(df_t[df_t["CT_PD"] == 1])

# %%
df_t = df_t[(df_t.CT_PD == 29) | (df_t.CT_PD == 30) | (df_t.CT_PD == 31)]

# %% [markdown]
# ## 연령, 성별에 따른 추가 분석

# %%
def category_age(x):
    if x < 10:
        return 0
    elif x < 20:
        return 1
    elif x < 30:
        return 2
    elif x < 40:
        return 3
    elif x < 50:
        return 4
    elif x < 60:
        return 5
    elif x < 70:
        return 6
    elif x < 80:
        return 7
    elif x < 90:
        return 8

# %%
df_t["AGE_CAT"] = df_t["AGE"].apply(category_age)
df_t
# Out:
# C:\Users\MULTIC~1\AppData\Local\Temp/ipykernel_10528/1160294.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t["AGE_CAT"] = df_t["AGE"].apply(category_age)
#         JOIN_SN  JOIN_SN_TYP  BTH_YR  GENDER  IS_KRN  AGE  SCTR_CD   COM_SN  \
# 2747     880454            1    1992       2       1   31        6     2443
# 2748     880454            1    1992       2       1   31        6     2443
# 2749     880454            1    1992       2       1   31        6     2443
# 2750     880454            1    1992       2       1   31        6     2443
# 2751     880454            1    1992       2       1   31        6     2443
# ...         ...          ...     ...     ...     ...  ...      ...      ...
# 543295   979312            1    2002       1       1   21        6  5695546
# 543296   979312            1    2002       1       1   21        6  5695546
# 543297   979312            1    2002       1       1   21        6  5695546
# 543298   979312            1    2002       1       1   21        6  5695546
# 543299   979312            1    2002       1       1   21        6  5695546
#
#          POL_SN  GIS_CD  ...  CT_PY_CYCLE_CD  CT_PY_PD CT_CHNL_CD MGG_GRP_CD  \
# 2747     545678      31  ...               1         0          7         A4
# 2748     545678      31  ...               1         0          7         A1
# 2749     545678      31  ...               1         0          7         A3
# 2750     545678      31  ...               1         0          7         A6
# 2751     545678      31  ...               1         0          7         A6
# ...         ...     ...  ...             ...       ...        ...        ...
# 543295  2137903      23  ...               1         0          5        A94
# 543296  2137903      23  ...               1         0          5         A3
# 543297  2137903      23  ...               1         0          5         A1
# 543298  2137903      23  ...               1         0          5        A94
# 543299  2137903      23  ...               1         0          5         A3
#
#         MGG_CD  MGG_CNT  MGG_AMT_SUM  MGG_GRP_CD_ CT_PD AGE_CAT
# 2747     A4199        1          160           진단    31       3
# 2748     A1100        1        16000           사망    31       3
# 2749     A3101        1        10000         후유장해    31       3
# 2750     A6300        1          100         입원일당    31       3
# 2751     A6100        1          100         입원일당    31       3
# ...        ...      ...          ...          ...   ...     ...
# 543295   A9499        1         1300          위로금    30       2
# 543296   A3101        1        10000         후유장해    30       2
# 543297   A1399        1       270000           사망    30       2
# 543298   A9499        1         1300          위로금    30       2
# 543299   A3101        1        10000         후유장해    30       2
#
# [799 rows x 25 columns]

# %%
df_t.groupby("AGE_CAT").CT_PY_AMT.mean()
# Out:
# AGE_CAT
# 1    11.000000
# 2    18.387387
# 3    19.131148
# 4    21.824818
# 5    28.333333
# 6    32.173913
# 7    66.500000
# 8    56.000000
# Name: CT_PY_AMT, dtype: float64

# %%
df_t.groupby("GENDER").count()
# Out:
#         JOIN_SN  JOIN_SN_TYP  BTH_YR  IS_KRN  AGE  SCTR_CD  COM_SN  POL_SN  \
# GENDER
# 1           396          396     396     396  396      396     396     396
# 2           403          403     403     403  403      403     403     403
#
#         GIS_CD  INS_GBN_CD  ...  CT_PY_CYCLE_CD  CT_PY_PD  CT_CHNL_CD  \
# GENDER                      ...
# 1          396         396  ...             396       396         396
# 2          403         403  ...             403       403         403
#
#         MGG_GRP_CD  MGG_CD  MGG_CNT  MGG_AMT_SUM  MGG_GRP_CD_  CT_PD  AGE_CAT
# GENDER
# 1              396     396      396          396          396    396      396
# 2              403     403      403          403          403    403      403
#
# [2 rows x 24 columns]

# %%
# 성별

gender_cnt = df_t.groupby("GENDER").count()
male = gender_cnt["JOIN_SN"][1]
female = gender_cnt["JOIN_SN"][2]

plt.pie([male, female], labels=["male", "female"])
plt.show()

# %%
# 연령
age_arr = []
labels = []

age_cnt = df_t.groupby("AGE_CAT").count()
for i in df_t["AGE_CAT"].unique():
    age_arr.append(age_cnt["JOIN_SN"][i])
    labels.append(i)
    
plt.pie(age_arr, labels=labels)
plt.show()

# %% [markdown]
# ---

# %%
dfs = {}
for a in df_t.MGG_GRP_CD_.unique():
    dfs[a] = df_t[df_t["MGG_GRP_CD_"] == a]

# %%
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
df_t.MGG_GRP_CD_.unique()
# Out:
# array(['진단', '사망', '후유장해', '입원일당', '기타', '위로금'], dtype=object)

# %%
df_t.groupby("GENDER").count()
# Out:
#         JOIN_SN  JOIN_SN_TYP  BTH_YR  IS_KRN  AGE  SCTR_CD  COM_SN  POL_SN  \
# GENDER
# 1           396          396     396     396  396      396     396     396
# 2           403          403     403     403  403      403     403     403
#
#         GIS_CD  INS_GBN_CD  ...  CT_PY_CYCLE_CD  CT_PY_PD  CT_CHNL_CD  \
# GENDER                      ...
# 1          396         396  ...             396       396         396
# 2          403         403  ...             403       403         403
#
#         MGG_GRP_CD  MGG_CD  MGG_CNT  MGG_AMT_SUM  MGG_GRP_CD_  CT_PD  AGE_CAT
# GENDER
# 1              396     396      396          396          396    396      396
# 2              403     403      403          403          403    403      403
#
# [2 rows x 24 columns]

# %%
# 보험담보그룹 별 성별 비율

for a in df_t.MGG_GRP_CD_.unique():
    arr = []
    labels = []
    df = dfs[a]
    df.groupby("GENDER").count()
    gender_cnt = df.groupby("GENDER").count()
    for i in df.GENDER.unique():
        arr.append(gender_cnt["JOIN_SN"][i])
        labels.append(i)
#     female = gender_cnt["JOIN_SN"][2]

#     labels = ["male", "female"]

    plt.pie(arr, labels=labels)
    plt.title(a)
    plt.show()

# %%
# 보험담보그룹 별 나이대 비율

for a in df_t.MGG_GRP_CD_.unique():
    df = dfs[a]
    age_cnt = df.groupby("AGE_CAT").count()
    age_arr = []
    labels = []
    print(df.AGE_CAT.unique())
#     print(age_cnt)
    for i in df.AGE_CAT.unique():
        if age_cnt["AGE"][i]:
            age_arr.append(age_cnt["AGE"][i])
            labels.append(i)
    plt.pie(age_arr, labels=labels)
    plt.title(a)
    plt.show()
# Out:
# [3 2]
# [3 5 4 6 2 7 8]
# [3 4 6 5 2 1 7 8]
# [3 2]
# [3 5 4 6 2 7]
# [3 4 6 5 2 1 8]

# %%
# 나이대별 보험담보그룹 비율

dfs_age = {}
for n in df_t.AGE_CAT.unique():
    dfs_age[n] = df_t[df_t["AGE_CAT"] == n]
    
for n in sorted(df_t.AGE_CAT.unique()):
    df = dfs_age[n]
    mgg_cnt = df.groupby("MGG_GRP_CD_").count()
    mgg_arr = []
    labels = []
    print(df.MGG_GRP_CD.unique())
#     print(age_cnt)
    for i in df.MGG_GRP_CD_.unique():
        if mgg_cnt["JOIN_SN"][i]:
            mgg_arr.append(mgg_cnt["JOIN_SN"][i])
            labels.append(i)
    plt.pie(mgg_arr, labels=labels)
    plt.title(f"{n}0대")
    plt.show()
# Out:
# ['A94' 'A3']
# ['A1' 'A3' 'A94' 'A99' 'A4' 'A6']
# ['A4' 'A1' 'A3' 'A6' 'A99' 'A94']
# ['A94' 'A1' 'A3' 'A99']
# ['A99' 'A1' 'A3' 'A94']
# ['A1' 'A3' 'A94' 'A99']
# ['A1' 'A99' 'A3']
# ['A1' 'A94' 'A3']

# %% [markdown]
# ---
