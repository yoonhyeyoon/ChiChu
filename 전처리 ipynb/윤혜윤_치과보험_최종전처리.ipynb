# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("preprocessed_5.csv")

# %%
df = df[df.INS_GBN_CD == 8]
df
# Out:
#         JOIN_SN  JOIN_SN_TYP  BTH_YR  GENDER  IS_KRN  AGE  SCTR_CD   COM_SN  \
# 46       537789            1    1973       2       1   50        3  5460366
# 47       537789            1    1973       2       1   50        3  5460366
# 48       537789            1    1973       2       1   50        3  5460366
# 319     1386093            1    2000       2       1   23        3  4626782
# 320     1386093            1    2000       2       1   23        3  4626782
# ...         ...          ...     ...     ...     ...  ...      ...      ...
# 407404  1225148            1    1989       2       1   34        6  6823861
# 407405  1225148            1    1989       2       1   34        6  6823861
# 407406  1225148            1    1989       2       1   34        6  6823861
# 407407  1225148            1    1989       2       1   34        6  6823861
# 407408  1225148            1    1989       2       1   34        6  6823861
#
# ...

# %%
df.columns
# Out:
# Index(['JOIN_SN', 'JOIN_SN_TYP', 'BTH_YR', 'GENDER', 'IS_KRN', 'AGE',
#        'SCTR_CD', 'COM_SN', 'POL_SN', 'GIS_CD', 'INS_GBN_CD', 'INS_CT_STAT_CD',
#        'CT_ST_DT', 'CT_END_DT', 'CT_PY_AMT', 'CT_PY_CYCLE_CD', 'CT_PY_PD',
#        'CT_CHNL_CD', 'INSU_DAYS', 'INSU_YEAR', 'MGG_GRP_CD', 'MGG_CD',
#        'MGG_CNT', 'MGG_AMT_SUM', 'PRODUCT', 'COMPANY'],
#       dtype='object')

# %%
df = df.drop(['IS_KRN', 'COM_SN', 'MGG_CD', 'MGG_CNT', 'MGG_AMT_SUM'], axis=1)
df
# Out:
#         JOIN_SN  JOIN_SN_TYP  BTH_YR  GENDER  AGE  SCTR_CD   POL_SN  GIS_CD  \
# 46       537789            1    1973       2   50        3   320238      11
# 47       537789            1    1973       2   50        3   320238      11
# 48       537789            1    1973       2   50        3   320238      11
# 319     1386093            1    2000       2   23        3  1365062      37
# 320     1386093            1    2000       2   23        3  1365062      37
# ...         ...          ...     ...     ...  ...      ...      ...     ...
# 407404  1225148            1    1989       2   34        6  4486972      39
# 407405  1225148            1    1989       2   34        6  4486972      39
# 407406  1225148            1    1989       2   34        6  1664157      39
# 407407  1225148            1    1989       2   34        6  1664157      39
# 407408  1225148            1    1989       2   34        6  1664157      39
#
# ...

# %%
df = df[df['MGG_GRP_CD'] == "A95"]

# %%
df = df[df['CT_PY_CYCLE_CD'] == 2]

# %%
df = df.drop(['CT_PY_CYCLE_CD'], axis=1)

# %%
df = df.drop(['JOIN_SN_TYP'], axis=1)

# %%
df.columns
# Out:
# Index(['JOIN_SN', 'BTH_YR', 'GENDER', 'AGE', 'SCTR_CD', 'POL_SN', 'GIS_CD',
#        'INS_GBN_CD', 'INS_CT_STAT_CD', 'CT_ST_DT', 'CT_END_DT', 'CT_PY_AMT',
#        'CT_PY_PD', 'CT_CHNL_CD', 'INSU_DAYS', 'INSU_YEAR', 'MGG_GRP_CD',
#        'PRODUCT', 'COMPANY'],
#       dtype='object')

# %%
df["AGE"] = df["AGE"] - 1

# %%
df = df.drop_duplicates()
df
# Out:
#         JOIN_SN  BTH_YR  GENDER  AGE  SCTR_CD   POL_SN  GIS_CD  INS_GBN_CD  \
# 46       537789    1973       2   49        3   320238      11           8
# 319     1386093    2000       2   22        3  1365062      37           8
# 322     1386093    2000       2   22        3  1365062      37           8
# 394      210105    1989       2   33        3  3770487      31           8
# 579     1195073    1979       2   43        6    71415      22           8
# ...         ...     ...     ...  ...      ...      ...     ...         ...
# 406513  1383012    1995       2   27        6  1273566      24           8
# 407155   555063    1987       2   35        8  8680189      11           8
# 407252  1058596    1977       1   45        8  5275797      11           8
# 407401  1225148    1989       2   33        6  4486972      39           8
# 407406  1225148    1989       2   33        6  1664157      39           8
#
# ...

# %%
# 업권코드, 증권코드 빼고 CT_ST_DT	CT_END_DT

# %%
df.groupby("JOIN_SN").count()
# Out:
#          BTH_YR  GENDER  AGE  SCTR_CD  POL_SN  GIS_CD  INS_GBN_CD  \
# JOIN_SN
# 1919          1       1    1        1       1       1           1
# 3785          2       2    2        2       2       2           2
# 4949          2       2    2        2       2       2           2
# 5001          1       1    1        1       1       1           1
# 7435          1       1    1        1       1       1           1
# ...         ...     ...  ...      ...     ...     ...         ...
# 1955136       1       1    1        1       1       1           1
# 1956550       1       1    1        1       1       1           1
# 1956642       2       2    2        2       2       2           2
# 1956868       1       1    1        1       1       1           1
# 1957740       2       2    2        2       2       2           2
#
#          INS_CT_STAT_CD  CT_ST_DT  CT_END_DT  CT_PY_AMT  CT_PY_PD  CT_CHNL_CD  \
# JOIN_SN
# ...

# %%
df.groupby("POL_SN").count()
# Out:
#          JOIN_SN  BTH_YR  GENDER  AGE  SCTR_CD  GIS_CD  INS_GBN_CD  \
# POL_SN
# 2869           1       1       1    1        1       1           1
# 3188           1       1       1    1        1       1           1
# 7504           1       1       1    1        1       1           1
# 7810           1       1       1    1        1       1           1
# 10661          1       1       1    1        1       1           1
# ...          ...     ...     ...  ...      ...     ...         ...
# 9969357        3       3       3    3        3       3           3
# 9979910        2       2       2    2        2       2           2
# 9991052        1       1       1    1        1       1           1
# 9991540        2       2       2    2        2       2           2
# 9995221        2       2       2    2        2       2           2
#
#          INS_CT_STAT_CD  CT_ST_DT  CT_END_DT  CT_PY_AMT  CT_PY_PD  CT_CHNL_CD  \
# POL_SN
# ...

# %%
2022 - 1957 - 1
# Out:
# 64

# %%
df = df[df["BTH_YR"] >= 1957]
df
# Out:
#         JOIN_SN  BTH_YR  GENDER  AGE  SCTR_CD   POL_SN  GIS_CD  INS_GBN_CD  \
# 46       537789    1973       2   49        3   320238      11           8
# 319     1386093    2000       2   22        3  1365062      37           8
# 322     1386093    2000       2   22        3  1365062      37           8
# 394      210105    1989       2   33        3  3770487      31           8
# 579     1195073    1979       2   43        6    71415      22           8
# ...         ...     ...     ...  ...      ...      ...     ...         ...
# 406513  1383012    1995       2   27        6  1273566      24           8
# 407155   555063    1987       2   35        8  8680189      11           8
# 407252  1058596    1977       1   45        8  5275797      11           8
# 407401  1225148    1989       2   33        6  4486972      39           8
# 407406  1225148    1989       2   33        6  1664157      39           8
#
# ...

# %%
df = df.drop(["POL_SN", "CT_ST_DT", "CT_END_DT", "SCTR_CD"], axis=1)

# %%
df
# Out:
#         JOIN_SN  BTH_YR  GENDER  AGE  GIS_CD  INS_GBN_CD  INS_CT_STAT_CD  \
# 46       537789    1973       2   49      11           8               2
# 319     1386093    2000       2   22      37           8               2
# 322     1386093    2000       2   22      37           8               2
# 394      210105    1989       2   33      31           8               2
# 579     1195073    1979       2   43      22           8               2
# ...         ...     ...     ...  ...     ...         ...             ...
# 406513  1383012    1995       2   27      24           8               2
# 407155   555063    1987       2   35      11           8               2
# 407252  1058596    1977       1   45      11           8               2
# 407401  1225148    1989       2   33      39           8               2
# 407406  1225148    1989       2   33      39           8               2
#
#         CT_PY_AMT  CT_PY_PD  CT_CHNL_CD  INSU_DAYS  INSU_YEAR MGG_GRP_CD  \
# ...

# %%
df.drop_duplicates()
# Out:
#         JOIN_SN  BTH_YR  GENDER  AGE  GIS_CD  INS_GBN_CD  INS_CT_STAT_CD  \
# 46       537789    1973       2   49      11           8               2
# 319     1386093    2000       2   22      37           8               2
# 322     1386093    2000       2   22      37           8               2
# 394      210105    1989       2   33      31           8               2
# 579     1195073    1979       2   43      22           8               2
# ...         ...     ...     ...  ...     ...         ...             ...
# 406513  1383012    1995       2   27      24           8               2
# 407155   555063    1987       2   35      11           8               2
# 407252  1058596    1977       1   45      11           8               2
# 407401  1225148    1989       2   33      39           8               2
# 407406  1225148    1989       2   33      39           8               2
#
#         CT_PY_AMT  CT_PY_PD  CT_CHNL_CD  INSU_DAYS  INSU_YEAR MGG_GRP_CD  \
# ...

# %%
df.to_csv(".", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\Users\MULTIC~1\AppData\Local\Temp/ipykernel_7932/603336121.py in <module>
# ----> 1 df.to_csv(".", index=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3561         )
#    3562
# -> 3563         return DataFrameRenderer(formatter).to_csv(
#    3564             path_or_buf,
#    3565             line_terminator=line_terminator,
#
# ...
